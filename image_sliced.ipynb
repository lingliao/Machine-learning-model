# %% [markdown]
# <a href="https://colab.research.google.com/github/lingliao/Machine-learning-model/blob/main/image_sliced.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install image-slicer
import image_slicer
import matplotlib.pyplot as plt
from skimage.io import imread
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import cv2

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
tiles=image_slicer.slice('tissue_hires_image.png',1000, save=False)

# %%
image_slicer.save_tiles(tiles, directory='/content/drive/MyDrive/sliced_image',\
                            prefix='test', format='png')

# %%
path ="tissue_hires_image_11_03.png"
img = imread(path)
plt.imshow(img)

# %%
path='/content/'

# %%
# !cp -r /content/ /content/drive/MyDrive/sliced_image/
# Out:
# cp: cannot stat '/content/gdrive': Transport endpoint is not connected
# cp: cannot open '/content/drive/MyDrive/Untitled spreadsheet.gsheet' for reading: Operation not supported
# cp: cannot copy a directory, '/content/', into itself, '/content/drive/MyDrive/sliced_image/content'

# %%
path ="tissue_hires_image_11_03.png"
img = imread(path)
plt.imshow(img)

# %%
import cv2 as cv
import glob
